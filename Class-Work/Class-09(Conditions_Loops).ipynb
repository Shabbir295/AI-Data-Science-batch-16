# %%
### Conditional Statement

    --- IF
    --- else
    --- elif
    --- nested if else

# %%
marks = int(input("Enter a MArks number"))
if marks >= 500:
  print(" 500 marks ")
elif marks >=400:
  print("   400 marks")
elif marks >= 300:
  print("  300 marks ")
else:
  print(" bhot kam hai ")
# Out:
# Enter a MArks number55
#  bhot kam hai

# %%
### NESTED IF ELSE

# %%
###  election  day
###  cnic
## age > 18
## vote mai name hon

# %%
election_day = input("Enter election day say yes or not")
if election_day  =="yes":      #  election
  print("YES aj election day ")


  cnic  = input("Enter a cnic  yes or no")
  if cnic == "yes":            # cnic
    print("CNIC HAI ")


    age = int(input("ENTER A AGE"))
    if age>=18:                  # age
      print("18 sal ka hai ")


      vote = input("Enter a Vote yes or no ")  #  ok
      if vote == "yes":
        print("AP VOTE MAI LIST HAI")

      else:
        print("AP ka name vote mai ni hai ")

    else:
      print("18 sai kam hai ")

  else:
    print("CNIC NI HAI ")

else:
  print("aj election ni hai ")

# %%
10  == 20
# Out:
# False

# %%
pin = 12345
balance = 50000

if pin == 12345:
  print("Valid PIN")
  if balance == 50000:
    print("balaned avilaible hai ")
  else:
    print("balned match ni kr rha")
else:
  print("Invalid pin")

# %%
## LOOP
    --- FOR LOOP
    --- While LOOP

# %%
print("ALi")
print("ALI")
print("ALi")
print("ALI")
print("ALi")
print("ALI")
print("ALi")

# %%
for aa in range(10):
  print("ALi")
# Out:
# ALi
# ALi
# ALi
# ALi
# ALi
# ALi
# ALi
# ALi
# ALi
# ALi

# %%
LOOP  :
      chakkar

# %%
for name in ["usman","ali","khan","man","kamran","ALI"]:
  print("HELLO   Hy", name)
# Out:
# HELLO   Hy usman
# HELLO   Hy ali
# HELLO   Hy khan
# HELLO   Hy man
# HELLO   Hy kamran
# HELLO   Hy ALI

# %%
for name in ["usman","ali","khan","man","kamran","ALI"]:
  print("aj off hy", name)
# Out:
# aj off hy usman
# aj off hy ali
# aj off hy khan
# aj off hy man
# aj off hy kamran
# aj off hy ALI

# %%
for a in range(20):
  if a%2  == 0:
    print(f"EVEN NUMBER   {a}")
  else:
    print(f" odd number  {a}")
# Out:
# EVEN NUMBER   0
#  odd number  1
# EVEN NUMBER   2
#  odd number  3
# EVEN NUMBER   4
#  odd number  5
# EVEN NUMBER   6
#  odd number  7
# EVEN NUMBER   8
#  odd number  9
# EVEN NUMBER   10
#  odd number  11
# EVEN NUMBER   12
#  odd number  13
# EVEN NUMBER   14
#  odd number  15
# EVEN NUMBER   16
#  odd number  17
# EVEN NUMBER   18
#  odd number  19

# %%
a=[1,  2,   4,   54,   6,  ,8,9,0,90]
  #0  #1    # 2

a[0:3]
# Out:
# [1, 2, 4]

# %%
for a in range(21):
  if a%2  == 0:
    print("EVEN NUMBER  ", a)
  else:
    print(" odd number ",a)
# Out:
# EVEN NUMBER   0
#  odd number  1
# EVEN NUMBER   2
#  odd number  3
# EVEN NUMBER   4
#  odd number  5
# EVEN NUMBER   6
#  odd number  7
# EVEN NUMBER   8
#  odd number  9
# EVEN NUMBER   10
#  odd number  11
# EVEN NUMBER   12
#  odd number  13
# EVEN NUMBER   14
#  odd number  15
# EVEN NUMBER   16
#  odd number  17
# EVEN NUMBER   18
#  odd number  19
# EVEN NUMBER   20

# %%
num = int(input("Enter a Number"))
for n in range(1,11):    #  n =   1,  n= 2,n = 3
  print(f"{num}   *  {n}  :   {num*n}")
# Out:
# Enter a Number3
# 3   *  1  :   3
# 3   *  2  :   6
# 3   *  3  :   9
# 3   *  4  :   12
# 3   *  5  :   15
# 3   *  6  :   18
# 3   *  7  :   21
# 3   *  8  :   24
# 3   *  9  :   27
# 3   *  10  :   30
