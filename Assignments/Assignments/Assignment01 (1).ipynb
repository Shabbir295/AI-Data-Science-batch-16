# %% [markdown]
# 1.**Student Information**
#
# - Create variables for a student's name, age, city, and student status.
#
# - Print all the information in a properly formatted output.

# %%
student = "Shabbir"
age = 15
city = "karachi"
student_status = "Active"

# %%
print("student:",student,"\nage:", age, "\ncity:", city, "\nstudent_status:",student_status)
# Out:
# student: Shabbir
# age: 15
# city: karachi
# student_status: Active

# %% [markdown]
# 2. **Data Types**
# - Create variables containing a string, integer, float, and boolean.
#
# - Print the value and data type of each variable using type().

# %%
string = "Shabbir"
integer = 78
floats = 78.7
boolean = True

# %%
print(string,type(string))
print(integer,type(integer))
print(floats,type(floats))
print(boolean,type(boolean))
# Out:
# Shabbir <class 'str'>
# 78 <class 'int'>
# 78.7 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# **3. Arithmetic Operations**
#
# - Create two number variables and calculate their:
#
# • Addition
#
# • Subtraction
#
# • Multiplication
#
# • Division
#
# • Modulus
#
# • Power

# %%
num1 = 56
num2 = 17

# %%
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
print(num1%num2)
print(num1**num2)
# Out:
# 73
# 39
# 952
# 3.2941176470588234
# 5
# 523837348053896201440996622336

# %% [markdown]
# **4. Student Marks Calculator**
# - Store the marks of three subjects in separate variables.
#
# - Calculate and print the total marks and average marks.

# %%
chemistry = 59
biology = 67
urdu = 91

# %%
total_marks = chemistry + biology + urdu
average_marks = total_marks / 3
print("Total_marks:",total_marks,"\nAverage Marks:",average_marks)
# Out:
# Total_marks: 217
# Average Marks: 72.33333333333333

# %% [markdown]
# **5. Shopping Bill**
# - Create variables for the product price and quantity.
# - Calculate and print the total bill

# %%
product_price = 150
product_quantity = 4

# %%
total_bill = product_price * product_quantity
print("Total Bill :", total_bill)
# Out:
# Total Bill : 600

# %% [markdown]
# **6. Rectangle Area**
# - Create variables for the length and width of a rectangle.
# - Calculate and print its area and perimeter.

# %%
length = 35
width = 20

# %%
area = length * width
perimeter = 2 *(length + width)
print("The Area Of Rectangle Is : ", area, "\nThe Perimeter Of Rectangle Is :",perimeter)
# Out:
# The Area Of Rectangle Is :  700
# The Perimeter Of Rectangle Is : 110

# %% [markdown]
# **7. Time Converter**
# - Store 250 minutes in a variable.
# - Calculate and print the number of hours and remaining minutes.

# %%
minutes = 250

# %%
hours = minutes // 60
remaining_min = minutes % 60
print("250 minutes =", hours ,"Hours or", remaining_min, "minutes")
# Out:
# 250 minutes = 4 Hours or 10 minutes

# %% [markdown]
# **8. Student Eligibility**
#
# - Create variables for marks and attendance.
#
# - A student is eligible if:
#
# - Marks are greater than or equal to 50
#
# - Attendance is greater than or equal to 75
#
# - Use logical operators to calculate and print whether the student is eligible.

# %%
marks = 95
attendance = 98

# %%
result = marks >= 50 and attendance >= 75
print(result)
# Out:
# True

# %% [markdown]
# **9. Logical Operators**
#
# - Create two Boolean variables:
#
# - a = True
#
# - b = False
#
#  -  Print the results of:
#
# - a and b
#
# - a or b
#
# - not a
#
# - not b

# %%
a = True
b = False

# %%
print(a and b)
print(a or b)
print(not a)
print(not b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# **Final Challenge Student Report**
#
# - Create variables for:
#
# • Student name
#
# • Age
#
# • Marks of 3 subjects
#
# • Attendance
#
# **Then:**
#
# 1. Print the student's information.
#
# 2. Calculate and print the total marks.
#
# 3. Calculate and print the average marks.
#
# 4. Use logical operators to calculate and print whether the student is eligible:
#
# o Average marks >= 50
#
# o Attendance >= 75
#
# **Restriction: Do not use if, else, or elif*

# %%
student_name = "Shabbir"
age = 15
biology = 69
urdu = 91
english = 78
attendance = 91

# %%
print("Student Name :",student_name,"\nage :",age,)
total_marks = biology + urdu + english
print("Total Marks :",total_marks)
average_marks = total_marks / 3
print("Average Marks :",average_marks)
eligibility_result = average_marks >= 50 and attendance >= 75
print("eligibility result :", eligibility_result)
# Out:
# Student Name : Shabbir
# age : 15
# Total Marks : 238
# Average Marks : 79.33333333333333
# eligibility result : True
